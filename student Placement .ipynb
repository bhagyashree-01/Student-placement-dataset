# %%
# student placement dataset 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("C:/Users/Bhagyashree.Kale/Downloads/archive (12)/college_student_placement_dataset.csv")

# %%
df.head(100)
# Out:
#    College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0     CLG0030  107             6.61  6.28                     8
# 1     CLG0061   97             5.52  5.37                     8
# 2     CLG0036  109             5.36  5.83                     9
# 3     CLG0055  122             5.47  5.75                     6
# 4     CLG0004   96             7.91  7.69                     7
# ..        ...  ...              ...   ...                   ...
# 95    CLG0043   78             8.07  8.41                     7
# 96    CLG0016  104             8.81  9.26                    10
# 97    CLG0014  103             7.73  7.77                     9
# 98    CLG0074  100             8.14  7.65                     3
# 99    CLG0019   96             9.68  9.19                     1
#
#    Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                     No                       8                     8
# ...

# %%
df.tail()
# Out:
#      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 9995    CLG0021  119             8.41  8.29                     4
# 9996    CLG0098   70             9.25  9.34                     7
# 9997    CLG0066   89             6.08  6.25                     3
# 9998    CLG0045  107             8.77  8.92                     3
# 9999    CLG0060  109             9.41  9.77                     8
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 9995                    No                       1                     8
# 9996                    No                       0                     7
# 9997                   Yes                       3                     9
# 9998                    No                       7                     5
# 9999                    No                       3                     5
#
#       Projects_Completed Placement
# 9995                   0       Yes
# 9996                   2        No
# ...

# %%
df.sample()
# Out:
#      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 5629    CLG0062  105             9.79  9.67                     8
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 5629                   Yes                       0                     3
#
#       Projects_Completed Placement
# 5629                   2        No

# %%
df.shape
# Out:
# (10000, 10)

# %%
df.columns
# Out:
# Index(['College_ID', 'IQ', 'Prev_Sem_Result', 'CGPA', 'Academic_Performance',
#        'Internship_Experience', 'Extra_Curricular_Score',
#        'Communication_Skills', 'Projects_Completed', 'Placement'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   College_ID              10000 non-null  object
#  1   IQ                      10000 non-null  int64
#  2   Prev_Sem_Result         10000 non-null  float64
#  3   CGPA                    10000 non-null  float64
#  4   Academic_Performance    10000 non-null  int64
#  5   Internship_Experience   10000 non-null  object
#  6   Extra_Curricular_Score  10000 non-null  int64
#  7   Communication_Skills    10000 non-null  int64
#  8   Projects_Completed      10000 non-null  int64
#  9   Placement               10000 non-null  object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 781.4+ KB

# %%
df.describe()
# Out:
#                  IQ  Prev_Sem_Result          CGPA  Academic_Performance  \
# count  10000.000000     10000.000000  10000.000000          10000.000000
# mean      99.471800         7.535673      7.532379              5.546400
# std       15.053101         1.447519      1.470141              2.873477
# min       41.000000         5.000000      4.540000              1.000000
# 25%       89.000000         6.290000      6.290000              3.000000
# 50%       99.000000         7.560000      7.550000              6.000000
# 75%      110.000000         8.790000      8.770000              8.000000
# max      158.000000        10.000000     10.460000             10.000000
#
#        Extra_Curricular_Score  Communication_Skills  Projects_Completed
# count            10000.000000          10000.000000        10000.000000
# mean                 4.970900              5.561800            2.513400
# std                  3.160103              2.900866            1.715959
# ...

# %%
df.describe(include='object')
# Out:
#        College_ID Internship_Experience Placement
# count       10000                 10000     10000
# unique        100                     2         2
# top       CLG0062                    No        No
# freq          133                  6036      8341

# %%
df.isnull().mean()*100
# Out:
# College_ID                0.0
# IQ                        0.0
# Prev_Sem_Result           0.0
# CGPA                      0.0
# Academic_Performance      0.0
# Internship_Experience     0.0
# Extra_Curricular_Score    0.0
# Communication_Skills      0.0
# Projects_Completed        0.0
# Placement                 0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# College_ID                100
# IQ                        104
# Prev_Sem_Result           501
# CGPA                      590
# Academic_Performance       10
# Internship_Experience       2
# Extra_Curricular_Score     11
# Communication_Skills       10
# Projects_Completed          6
# Placement                   2
# dtype: int64

# %%
df['Placement'].value_counts()
# Out:
# Placement
# No     8341
# Yes    1659
# Name: count, dtype: int64

# %%
df['Internship_Experience'].value_counts(normalize=True)
# Out:
# Internship_Experience
# No     0.6036
# Yes    0.3964
# Name: proportion, dtype: float64

# %%
df.corr(numeric_only=True)
# Out:
#                               IQ  Prev_Sem_Result      CGPA  \
# IQ                      1.000000        -0.002640 -0.002859
# Prev_Sem_Result        -0.002640         1.000000  0.980768
# CGPA                   -0.002859         0.980768  1.000000
# Academic_Performance   -0.006827        -0.005765 -0.002958
# Extra_Curricular_Score -0.003458         0.009326  0.011441
# Communication_Skills   -0.010896        -0.017269 -0.018242
# Projects_Completed      0.014538         0.018434  0.020872
#
#                         Academic_Performance  Extra_Curricular_Score  \
# IQ                                 -0.006827               -0.003458
# Prev_Sem_Result                    -0.005765                0.009326
# CGPA                               -0.002958                0.011441
# Academic_Performance                1.000000                0.011774
# Extra_Curricular_Score              0.011774                1.000000
# ...

# %%
df.groupby('Placement')['CGPA'].mean()
# Out:
# Placement
# No     7.321527
# Yes    8.592483
# Name: CGPA, dtype: float64

# %%
df.groupby('Internship_Experience')['Placement'].value_counts()
# Out:
# Internship_Experience  Placement
# No                     No           5024
#                        Yes          1012
# Yes                    No           3317
#                        Yes           647
# Name: count, dtype: int64

# %%
df.sort_values(by='CGPA', ascending=False)
# Out:
#      College_ID   IQ  Prev_Sem_Result   CGPA  Academic_Performance  \
# 5999    CLG0076   82             9.99  10.46                     1
# 4004    CLG0027   79            10.00  10.46                     1
# 2277    CLG0072   82             9.99  10.45                     4
# 9769    CLG0065   73             9.98  10.45                     6
# 8418    CLG0010   91             9.97  10.44                     7
# ...         ...  ...              ...    ...                   ...
# 6758    CLG0067  130             5.04   4.59                     3
# 3332    CLG0005  123             5.02   4.58                     3
# 8574    CLG0025   97             5.06   4.57                     6
# 8835    CLG0017   99             5.01   4.56                     5
# 9333    CLG0044  113             5.03   4.54                     6
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 5999                    No                       6                     7
# ...

# %%
df[df['CGPA'] > 8]
# Out:
#      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 7       CLG0096  111             8.77  8.76                     7
# 9       CLG0057  108             8.82  8.60                     4
# 10      CLG0063   93             8.73  8.90                     2
# 12      CLG0064  103             8.64  9.01                     7
# 13      CLG0017   71             8.74  8.40                     6
# ...         ...  ...              ...   ...                   ...
# 9994    CLG0064  117             8.71  8.44                     6
# 9995    CLG0021  119             8.41  8.29                     4
# 9996    CLG0098   70             9.25  9.34                     7
# 9998    CLG0045  107             8.77  8.92                     3
# 9999    CLG0060  109             9.41  9.77                     8
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 7                       No                       3                     1
# ...

# %%
df[df['Placement'] == 'Yes']
# Out:
#      College_ID   IQ  Prev_Sem_Result   CGPA  Academic_Performance  \
# 6       CLG0071  123             6.68   6.58                     5
# 7       CLG0096  111             8.77   8.76                     7
# 18      CLG0068   86             8.20   8.15                     7
# 20      CLG0072  121             8.41   8.07                     5
# 23      CLG0087   78             8.67   9.17                     7
# ...         ...  ...              ...    ...                   ...
# 9964    CLG0090  123             9.93  10.01                     6
# 9978    CLG0056   84             9.87   9.69                     7
# 9992    CLG0062  109             9.92  10.09                     2
# 9994    CLG0064  117             8.71   8.44                     6
# 9995    CLG0021  119             8.41   8.29                     4
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 6                       No                       7                     8
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Placement', data=df)
plt.show()

sns.boxplot(x='Placement', y='CGPA', data=df)
plt.show()

# %%
df.isnull().sum()
# Out:
# College_ID                0
# IQ                        0
# Prev_Sem_Result           0
# CGPA                      0
# Academic_Performance      0
# Internship_Experience     0
# Extra_Curricular_Score    0
# Communication_Skills      0
# Projects_Completed        0
# Placement                 0
# Overall_Score             0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# College_ID                10000
# IQ                        10000
# Prev_Sem_Result           10000
# CGPA                      10000
# Academic_Performance      10000
# Internship_Experience     10000
# Extra_Curricular_Score    10000
# Communication_Skills      10000
# Projects_Completed        10000
# Placement                 10000
# Overall_Score             10000
# dtype: int64

# %%
df.dropna()
# Out:
#      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0       CLG0030  107             6.61  6.28                     8
# 1       CLG0061   97             5.52  5.37                     8
# 2       CLG0036  109             5.36  5.83                     9
# 3       CLG0055  122             5.47  5.75                     6
# 4       CLG0004   96             7.91  7.69                     7
# ...         ...  ...              ...   ...                   ...
# 9995    CLG0021  119             8.41  8.29                     4
# 9996    CLG0098   70             9.25  9.34                     7
# 9997    CLG0066   89             6.08  6.25                     3
# 9998    CLG0045  107             8.77  8.92                     3
# 9999    CLG0060  109             9.41  9.77                     8
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                       No                       8                     8
# ...

# %%
df["IQ"].describe()
# Out:
# count    10000.000000
# mean        99.471800
# std         15.053101
# min         41.000000
# 25%         89.000000
# 50%         99.000000
# 75%        110.000000
# max        158.000000
# Name: IQ, dtype: float64

# %%
df["Prev_Sem_Result"].describe()
# Out:
# count    10000.000000
# mean         7.535673
# std          1.447519
# min          5.000000
# 25%          6.290000
# 50%          7.560000
# 75%          8.790000
# max         10.000000
# Name: Prev_Sem_Result, dtype: float64

# %%
df["CGPA"].describe()
# Out:
# count    10000.000000
# mean         7.532379
# std          1.470141
# min          4.540000
# 25%          6.290000
# 50%          7.550000
# 75%          8.770000
# max         10.460000
# Name: CGPA, dtype: float64

# %%
df["Academic_Performance"].describe()
# Out:
# count    10000.000000
# mean         5.546400
# std          2.873477
# min          1.000000
# 25%          3.000000
# 50%          6.000000
# 75%          8.000000
# max         10.000000
# Name: Academic_Performance, dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("C:/Users/Bhagyashree.Kale/Downloads/archive (12)/college_student_placement_dataset.csv")
col = 'CGPA'
# Box plot
sns.boxplot(y=df[col])
plt.title('Boxplot to detect outliers')
plt.show()

# Detect outliers
Q1 = df[col].quantile(0.25)
Q3 = df[col].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(y=df['IQ'])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(y=df['CGPA'])
plt.show()

# %%
df.IQ.mean()
# Out:
# np.float64(99.4718)

# %%
df.IQ.std()
# Out:
# np.float64(15.053101485954137)

# %%
Q1 = df.IQ.quantile(0.25)
Q3 = df.IQ.quantile(0.75)
Q1,Q3
# Out:
# (np.float64(89.0), np.float64(110.0))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(y=df['IQ'])
plt.show()

# %%
import pandas as pd
df = pd.read_csv("C:/Users/Bhagyashree.Kale/Downloads/archive (12)/college_student_placement_dataset.csv")  
col = 'IQ'
Q1 = df[col].quantile(0.25)
Q3 = df[col].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
df=pd.read_csv("cleaned_student_data.csv")
df_clean.describe()
# Out:
#                 IQ  Prev_Sem_Result         CGPA  Academic_Performance  \
# count  9939.000000      9939.000000  9939.000000           9939.000000
# mean     99.492907         7.534261     7.531134              5.549351
# std      14.654855         1.446964     1.469237              2.874243
# min      58.000000         5.000000     4.540000              1.000000
# 25%      89.500000         6.290000     6.290000              3.000000
# 50%      99.000000         7.550000     7.550000              6.000000
# 75%     109.500000         8.780000     8.770000              8.000000
# max     141.000000        10.000000    10.460000             10.000000
#
#        Extra_Curricular_Score  Communication_Skills  Projects_Completed
# count             9939.000000           9939.000000         9939.000000
# mean                 4.969715              5.556092            2.513834
# std                  3.159347              2.902374            1.715439
# ...

# %%
import pandas as pd
df = pd.read_csv("C:/Users/Bhagyashree.Kale/Downloads/archive (12)/college_student_placement_dataset.csv")
Q1 = df['IQ'].quantile(0.25)
Q3 = df['IQ'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(lower_bound)
print(upper_bound)
# Out:
# 57.5
# 141.5

# %%
df.equals(df.copy())
# Out:
# True

# %%
df.columns.is_unique
# Out:
# True

# %%
df.index.is_unique
# Out:
# True

# %%
df.isin(['Yes','No']).sum()
# Out:
# College_ID                    0
# IQ                            0
# Prev_Sem_Result               0
# CGPA                          0
# Academic_Performance          0
# Internship_Experience     10000
# Extra_Curricular_Score        0
# Communication_Skills          0
# Projects_Completed            0
# Placement                 10000
# dtype: int64

# %%
df.loc[df['Placement']=='Yes', 'CGPA'].mean()
# Out:
# np.float64(8.592483423749247)

# %%
df.loc[df['Placement']=='No', 'IQ'].median()
# Out:
# np.float64(98.0)

# %%
df.groupby('Placement')['CGPA'].describe()
# Out:
#             count      mean       std   min    25%   50%   75%    max
# Placement
# No         8341.0  7.321527  1.435644  4.54  6.120  7.26  8.48  10.46
# Yes        1659.0  8.592483  1.148343  4.58  8.205  8.76  9.41  10.46

# %%
df['CGPA'].quantile([0.1, 0.25, 0.5, 0.75, 0.9])
# Out:
# 0.10    5.52
# 0.25    6.29
# 0.50    7.55
# 0.75    8.77
# 0.90    9.50
# Name: CGPA, dtype: float64

# %%
np.percentile(df['IQ'], [10, 25, 50, 75, 90])
# Out:
# array([ 80.,  89.,  99., 110., 119.])

# %%
df.corr(method='pearson', numeric_only=True)
# Out:
#                               IQ  Prev_Sem_Result      CGPA  \
# IQ                      1.000000        -0.002640 -0.002859
# Prev_Sem_Result        -0.002640         1.000000  0.980768
# CGPA                   -0.002859         0.980768  1.000000
# Academic_Performance   -0.006827        -0.005765 -0.002958
# Extra_Curricular_Score -0.003458         0.009326  0.011441
# Communication_Skills   -0.010896        -0.017269 -0.018242
# Projects_Completed      0.014538         0.018434  0.020872
#
#                         Academic_Performance  Extra_Curricular_Score  \
# IQ                                 -0.006827               -0.003458
# Prev_Sem_Result                    -0.005765                0.009326
# CGPA                               -0.002958                0.011441
# Academic_Performance                1.000000                0.011774
# Extra_Curricular_Score              0.011774                1.000000
# ...

# %%
df.corr(method='spearman', numeric_only=True)
# Out:
#                               IQ  Prev_Sem_Result      CGPA  \
# IQ                      1.000000        -0.002730 -0.003022
# Prev_Sem_Result        -0.002730         1.000000  0.981761
# CGPA                   -0.003022         0.981761  1.000000
# Academic_Performance   -0.006674        -0.005762 -0.003106
# Extra_Curricular_Score -0.006193         0.009541  0.011770
# Communication_Skills   -0.009028        -0.017236 -0.019008
# Projects_Completed      0.016845         0.018430  0.020298
#
#                         Academic_Performance  Extra_Curricular_Score  \
# IQ                                 -0.006674               -0.006193
# Prev_Sem_Result                    -0.005762                0.009541
# CGPA                               -0.003106                0.011770
# Academic_Performance                1.000000                0.011822
# Extra_Curricular_Score              0.011822                1.000000
# ...

# %%
df.corr(method='kendall', numeric_only=True)
# Out:
#                               IQ  Prev_Sem_Result      CGPA  \
# IQ                      1.000000        -0.001956 -0.002157
# Prev_Sem_Result        -0.001956         1.000000  0.875590
# CGPA                   -0.002157         0.875590  1.000000
# Academic_Performance   -0.004653        -0.003991 -0.002179
# Extra_Curricular_Score -0.004373         0.006607  0.008182
# Communication_Skills   -0.006375        -0.012040 -0.013289
# Projects_Completed      0.012230         0.013367  0.014718
#
#                         Academic_Performance  Extra_Curricular_Score  \
# IQ                                 -0.004653               -0.004373
# Prev_Sem_Result                    -0.003991                0.006607
# CGPA                               -0.002179                0.008182
# Academic_Performance                1.000000                0.008616
# Extra_Curricular_Score              0.008616                1.000000
# ...

# %%
df.groupby('Placement')[['CGPA','IQ','Projects_Completed']].mean()
# Out:
#                CGPA          IQ  Projects_Completed
# Placement
# No         7.321527   97.552452            2.346961
# Yes        8.592483  109.121760            3.350211

# %%
df.var(numeric_only=True)
# Out:
# IQ                        226.595864
# Prev_Sem_Result             2.095311
# CGPA                        2.161315
# Academic_Performance        8.256873
# Extra_Curricular_Score      9.986252
# Communication_Skills        8.415022
# Projects_Completed          2.944515
# dtype: float64

# %%
df.sem(numeric_only=True)
# Out:
# IQ                        0.150531
# Prev_Sem_Result           0.014475
# CGPA                      0.014701
# Academic_Performance      0.028735
# Extra_Curricular_Score    0.031601
# Communication_Skills      0.029009
# Projects_Completed        0.017160
# dtype: float64

# %%
sns.kdeplot(data=df, x='CGPA', hue='Placement')
plt.show()

# %%
sns.violinplot(x='Placement', y='IQ', data=df)
plt.show()

# %%
(df['Placement']=='Yes').sum()
# Out:
# np.int64(1659)

# %%
(df['Internship_Experience']=='Yes').sum()
# Out:
# np.int64(3964)

# %%
df[(df['CGPA']>8) & (df['Placement']=='Yes')].shape[0]
# Out:
# 1376

# %%
pd.crosstab(df['IQ_Level'], df['Placement'], normalize='index')
# Out:
# Placement        No       Yes
# IQ_Level
# Low        0.917792  0.082208
# Mid        0.914859  0.085141
# High       0.909527  0.090473
# Very High  0.564361  0.435639

# %%
df.nlargest(10, 'CGPA')
# Out:
#      College_ID   IQ  Prev_Sem_Result   CGPA  Academic_Performance  \
# 4004    CLG0027   79            10.00  10.46                     1
# 5999    CLG0076   82             9.99  10.46                     1
# 2277    CLG0072   82             9.99  10.45                     4
# 9769    CLG0065   73             9.98  10.45                     6
# 8418    CLG0010   91             9.97  10.44                     7
# 2081    CLG0054  109             9.96  10.42                    10
# 5813    CLG0089   87             9.95  10.42                    10
# 8164    CLG0059   73             9.95  10.41                     1
# 4699    CLG0044   92             9.96  10.40                     3
# 8374    CLG0067   97             9.93  10.40                     3
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 4004                   Yes                       1                     9
# 5999                    No                       6                     7
# ...

# %%
df.nsmallest(10, 'CGPA')
# Out:
#      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 9333    CLG0044  113             5.03  4.54                     6
# 8835    CLG0017   99             5.01  4.56                     5
# 8574    CLG0025   97             5.06  4.57                     6
# 3332    CLG0005  123             5.02  4.58                     3
# 319     CLG0029   98             5.03  4.59                    10
# 4147    CLG0090   98             5.06  4.59                     8
# 6758    CLG0067  130             5.04  4.59                     3
# 7761    CLG0011  110             5.04  4.60                     1
# 8917    CLG0050   92             5.09  4.60                     8
# 417     CLG0023  101             5.02  4.61                     5
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 9333                   Yes                       9                     5
# 8835                   Yes                       0                     9
# ...

# %%
df.query("CGPA > 8 and Internship_Experience == 'Yes' and Placement == 'No'")
# Out:
#      College_ID   IQ  Prev_Sem_Result   CGPA  Academic_Performance  \
# 10      CLG0063   93             8.73   8.90                     2
# 12      CLG0064  103             8.64   9.01                     7
# 17      CLG0050  104             9.61  10.01                    10
# 22      CLG0030  101             7.96   8.22                     2
# 29      CLG0025   95             9.18   9.61                     4
# ...         ...  ...              ...    ...                   ...
# 9965    CLG0071  107             9.68   9.35                     1
# 9968    CLG0073  100             8.73   8.75                     8
# 9976    CLG0005  125             8.60   8.62                     4
# 9980    CLG0075   93             8.32   8.48                     7
# 9986    CLG0027   94             8.66   8.19                     8
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 10                     Yes                       5                     6
# ...

# %%
from scipy.stats import entropy
entropy(df['Placement'].value_counts())
# Out:
# np.float64(0.4493251878648596)

# %%
pd.crosstab(df['Internship_Experience'], df['Placement'])
# Out:
# Placement                No   Yes
# Internship_Experience
# No                     5024  1012
# Yes                    3317   647

# %%
pd.crosstab(df['Projects_Completed'], df['Placement'], normalize='columns')
# Out:
# Placement                 No       Yes
# Projects_Completed
# 0                   0.196979  0.027125
# 1                   0.188946  0.019892
# 2                   0.152739  0.245329
# 3                   0.148423  0.234479
# 4                   0.157295  0.229656
# 5                   0.155617  0.243520

# %%
df.sample(frac=0.1, random_state=42)
# Out:
#      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 6252    CLG0029  139             7.29  7.24                     8
# 4684    CLG0070   84             8.28  8.49                     8
# 1731    CLG0008   94             5.26  5.66                     8
# 4742    CLG0097  100             6.22  6.29                     6
# 4521    CLG0019  116             5.99  6.39                     6
# ...         ...  ...              ...   ...                   ...
# 3921    CLG0089  103             6.82  6.43                    10
# 6685    CLG0025  102             6.99  7.11                     9
# 3194    CLG0079   76             7.94  8.34                     1
# 1941    CLG0015   94             8.54  8.99                     9
# 7713    CLG0063  104             6.50  6.16                    10
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 6252                    No                       8                     4
# ...

# %%
df.apply(lambda x: x.nunique())
# Out:
# College_ID                 100
# IQ                         104
# Prev_Sem_Result            501
# CGPA                       590
# Academic_Performance        10
# Internship_Experience        2
# Extra_Curricular_Score      11
# Communication_Skills        10
# Projects_Completed           6
# Placement                    2
# IQ_Level                     4
# CGPA_Rolling_Avg          5049
# IQ_Rank                    104
# dtype: int64

# %%
df.apply(lambda x: x.isnull().sum())
# Out:
# College_ID                 0
# IQ                         0
# Prev_Sem_Result            0
# CGPA                       0
# Academic_Performance       0
# Internship_Experience      0
# Extra_Curricular_Score     0
# Communication_Skills       0
# Projects_Completed         0
# Placement                  0
# IQ_Level                   0
# CGPA_Rolling_Avg          49
# IQ_Rank                    0
# dtype: int64

# %%
df.apply(lambda x: x.value_counts().head(3))
# Out:
#          College_ID     IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0               NaN    NaN              NaN   NaN                   NaN
# 3               NaN    NaN              NaN   NaN                   NaN
# 4               NaN    NaN              NaN   NaN                   NaN
# 5               NaN    NaN              NaN   NaN                   NaN
# 5.93            NaN    NaN             35.0   NaN                   NaN
# 6.72            NaN    NaN              NaN  32.0                   NaN
# 7               NaN    NaN              NaN   NaN                1027.0
# 7.29            NaN    NaN              NaN  32.0                   NaN
# 7.34            NaN    NaN             35.0   NaN                   NaN
# 7.495           NaN    NaN              NaN   NaN                   NaN
# 7.515           NaN    NaN              NaN   NaN                   NaN
# 7.5586          NaN    NaN              NaN   NaN                   NaN
# ...
